# %% [markdown]
# **PARTE 1: análisis del corpus**

# %%
import nltk
from nltk import ngrams
from nltk.classify import accuracy, NaiveBayesClassifier
from nltk.corpus import senseval
from nltk.corpus import wordnet

#Descarga de información
nltk.download('senseval')
nltk.download('wordnet')

print('\n\nPalabras del paquete senseval: ', senseval.fileids())


#Se guardan las estructuras correspondientes a cada palabra
interest = senseval.instances('interest.pos')
hard = senseval.instances('hard.pos')
line = senseval.instances('line.pos')
serve = senseval.instances('serve.pos')

#Mostramos un ejemplo del contenido de una instancia de hard.pos con sus diferentes campos
instance_hard = hard[2]
print('\n************************* Información de ejemplo de hard del paquete senseval ****************\n')
print('Información de función de la palabra: ', instance_hard.word)
print('Posición de la palabra en la frase del contexto: ', instance_hard.position)
print('Diferentes sentidos de la palabra ambigua: ', instance_hard.senses)
print('Contexto de la palabra: ', instance_hard.context)
print('****************************************************************************\n')

#devuelve el número de una cadena tipo HARD1
def splitNumero(s):
  if (not '_' in s):
    numero = s.split('.')[2]
  else:
    numero = s.replace('_', '.').split('.')[3]
    #Se busca el índice codificado al final sin ceros y restándole uno para que comience en cero
  return (int(numero) -1)

#devuelve la palabra que antecede al número de una cadena tipo HARD1
def splitPalabra(s):
  #se buscar en wordnet la primera palabra que aparece en el campo de sense
  palabra = s.replace('_', '.').split('.')[0]
  return palabra

#Inicialización variables entidos de las palabras ambiguas: hard, interest, line y serve
num_hard_senses = 0
dict_hard_words = {}
dict_hard_words_num = {}

num_line_senses = 0
dict_line_words = {}
dict_line_words_num = {}

num_interest_senses = 0
dict_interest_words = {}
dict_interest_words_num = {}

num_serve_senses = 0
dict_serve_words = {}
dict_serve_words_num = {}

# A map of SENSEVAL senses to WordNet 3.0 senses.
# SENSEVAL-2 uses WordNet 1.7, which is no longer installable on most modern
# machines and is not the version that the NLTK comes with.
# As a consequence, we have to manually map the following
# senses to their equivalent(s).
SV_SENSE_MAP = {
    "HARD1": ["difficult.a.01"],    # not easy, requiring great physical or mental
    "HARD2": ["hard.a.02",          # dispassionate
              "difficult.a.01"],
    "HARD3": ["hard.a.03"],         # resisting weight or pressure
    "interest_1": ["interest.n.01"], # readiness to give attention
    "interest_2": ["interest.n.03"], # quality of causing attention to be given to
    "interest_3": ["pastime.n.01"],  # activity, etc. that one gives attention to
    "interest_4": ["sake.n.01"],     # advantage, advancement or favor
    "interest_5": ["interest.n.05"], # a share in a company or business
    "interest_6": ["interest.n.04"], # money paid for the use of money
    "cord": ["line.n.18"],          # something (as a cord or rope) that is long and thin and flexible
    "formation": ["line.n.01","line.n.03"], # a formation of people or things one beside another
    "text": ["line.n.05"],                 # text consisting of a row of words written across a page or computer screen
    "phone": ["telephone_line.n.02"],   # a telephone connection
    "product": ["line.n.22"],       # a particular kind of product or merchandise
    "division": ["line.n.29"],      # a conceptual separation or distinction
    "SERVE12": ["serve.v.02"],       # do duty or hold offices; serve in a specific function
    "SERVE10": ["serve.v.06"], # provide (usually but not necessarily food)
    "SERVE2": ["serve.v.01"],       # serve a purpose, role, or function
    "SERVE6": ["service.v.01"]      # be used by; as of a utility
}

def evaluaSentidos(objeto_palabra, nombre_palabra, num_senses, dict_words, dict_words_num):
  for w in objeto_palabra:
    for s in range(len(w.senses)):
      word =  w.senses[s]
      if (word not in dict_words):
        num_sense = splitNumero(SV_SENSE_MAP[word][0])
        short_word = splitPalabra(SV_SENSE_MAP[word][0])
        dict_words.update({word:wordnet.synsets(short_word)[num_sense].definition()})
      if (word not in dict_words_num):
        dict_words_num.update({word:1})
      else:
        dict_words_num.update({word:dict_words_num[word]+1})
  print('\n\n**************** Posibles significados de la palabra', nombre_palabra, ': ******************')
  print(dict_words)
  print('\nNúmero de ocurrencias de los significados de la palabra', nombre_palabra ,':')
  print(dict_words_num)
  print('************************************************************************')
  return (dict_words, dict_words_num)

#LLamadas a la función para las 4 palabras
evaluaSentidos(hard, 'hard', num_hard_senses, dict_hard_words, dict_hard_words_num)
evaluaSentidos(interest, 'interest', num_interest_senses, dict_interest_words, dict_interest_words_num)
evaluaSentidos(serve, 'serve', num_serve_senses, dict_serve_words, dict_serve_words_num)
evaluaSentidos(line, 'line', num_line_senses, dict_line_words, dict_line_words_num)

def calculaVar(dict_var, word):
  for w in word:
    for wc in w.context:
      word_var = wc[0].lower()
      if (word_var in dict_var.keys()):
          dict_var[word_var]+=1
  return dict_var

#Inicilialización del diccionario de cada palabra con sus variaciones y número de ocurrencias
dict_var_hard = {'hard':0, 'harder':0, 'hardest':0}
dict_var_interest = {'interest':0, 'interests':0, 'interested':0}
dict_var_line = {'line':0, 'liner':0,'lines':0, 'lined':0}
dict_var_serve = {'serve':0, 'served':0, 'serving':0, 'serves':0}

calculaVar(dict_var_hard, hard)
calculaVar(dict_var_interest, interest)
calculaVar(dict_var_line, line)
calculaVar(dict_var_serve, serve)

print('\n\n***************************************************************************************')
print('\tOCURRENCIAS DE VARIACIONES GRAMATICALES DE LAS PALABRAS')
print('\nOcurrencias de las variaciones de hard: ', dict_var_hard)
print('Ocurrencias de las variaciones de serve: ', dict_var_serve)
print('Ocurrencias de las variaciones de line: ', dict_var_line)
print('Ocurrencias de as variaciones de interest: ', dict_var_interest)
print('\n***************************************************************************************\n')


#Datos erróneos, en la instancia 999 se comprueba que en vez de una tupla (palabra, categoría gramatical) se tiene ta solola palabra clave FRASL
print('\n\n***********************************************\nDatos erróneos:')
def checkFormat(word, word_text):
  i=0
  fine_word = []
  for w in word:
    for wc in w.context:
      if (len(wc) !=2):
        print('Instancia nº ', i, ' de  ',word_text, ' mal formateada.')
        break
      fine_word.append(w)
    i+=1
  return fine_word

print('\n\nInstancias de hard antes de checkear las etiquetas  del contexto: ', len(hard))
hard = checkFormat(hard, 'hard')
print('\nInstancias de hard después de checkear las etiquetas  del contexto: ', len(hard))

print('\nInstancias de line antes de checkear las etiquetas  del contexto: ', len(line))
line = checkFormat(line, 'line')
print('\nInstancias de line después de checkear las etiquetas  del contexto: ', len(line))

print('\nInstancias de serve antes de checkear las etiquetas  del contexto: ', len(serve))
serve = checkFormat(serve, 'serve')
print('\nInstancias de serve después de checkear las etiquetas  del contexto: ', len(serve))

print('\nInstancias de interest antes de checkear las etiquetas  del contexto: ', len(interest))
interest = checkFormat(interest, 'interest')
print('\nInstancias de interest después de checkear las etiquetas  del contexto: ', len(interest))

#hard.remove(999)
# Out:
# [nltk_data] Downloading package senseval to /root/nltk_data...
# [nltk_data]   Package senseval is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#
#
# Palabras del paquete senseval:  ['hard.pos', 'interest.pos', 'line.pos', 'serve.pos']
#
# ************************* Información de ejemplo de hard del paquete senseval ****************
#
# Información de función de la palabra:  hard-a
# Posición de la palabra en la frase del contexto:  3
# Diferentes sentidos de la palabra ambigua:  ('HARD1',)
# Contexto de la palabra:  [('i', 'PRP'), ('find', 'VBP'), ('it', 'PRP'), ('hard', 'JJ'), ('to', 'TO'), ('believe', 'VB'), ('that', 'IN'), ('the', 'DT'), ('sacramento', 'NNP'), ('river', 'NNP'), ('will', 'MD'), ('ever', 'RB'), ('be', 'VB'), ('quite', 'RB'), ('the', 'DT'), ('same', 'JJ'), (',', ','), ('although', 'IN'), ('i', 'PRP'), ('certainly', 'RB'), ('wish', 'VBP'), ('that', 'IN'), ('i', 'PRP'), ("'m", 'VBP'), ('wrong', 'JJ'), ('.', '.')]
# ****************************************************************************
#
#
#
# **************** Posibles significados de la palabra hard : ******************
# {'HARD1': 'not easy; requiring great physical or mental effort to accomplish or comprehend or endure', 'HARD2': 'dispassionate; ', 'HARD3': 'resisting weight or pressure'}
#
# Número de ocurrencias de los significados de la palabra hard :
# {'HARD1': 3455, 'HARD2': 502, 'HARD3': 376}
# ************************************************************************
#
#
# **************** Posibles significados de la palabra interest : ******************
# {'interest_6': 'a fixed charge for borrowing money; usually a percentage of the amount borrowed', 'interest_5': '(law) a right or legal share of something; a financial involvement with something', 'interest_4': 'a reason for wanting something done', 'interest_1': 'a sense of concern with and curiosity about someone or something', 'interest_3': "a diversion that occupies one's time and thoughts (usually pleasantly)", 'interest_2': "the power of attracting or holding one's attention (because it is unusual or exciting etc.)"}
#
# Número de ocurrencias de los significados de la palabra interest :
# {'interest_6': 1252, 'interest_5': 500, 'interest_4': 178, 'interest_1': 361, 'interest_3': 66, 'interest_2': 11}
# ************************************************************************
#
#
# **************** Posibles significados de la palabra serve : ******************
# {'SERVE10': 'help to some food; help with food or drink', 'SERVE12': 'serve a purpose, role, or function', 'SERVE2': '(sports) a stroke that puts the ball in play', 'SERVE6': 'work done by one person or group that benefits another'}
#
# Número de ocurrencias de los significados de la palabra serve :
# {'SERVE10': 1814, 'SERVE12': 1272, 'SERVE2': 853, 'SERVE6': 439}
# ************************************************************************
#
#
# **************** Posibles significados de la palabra line : ******************
# {'cord': 'something (as a cord or rope) that is long and thin and flexible', 'division': 'a conceptual separation or distinction', 'formation': 'a formation of people or things one beside another', 'phone': 'transmitting speech at a distance', 'product': 'a particular kind of product or merchandise', 'text': 'text consisting of a row of words written across a page or computer screen'}
#
# Número de ocurrencias de los significados de la palabra line :
# {'cord': 373, 'division': 374, 'formation': 349, 'phone': 429, 'product': 2217, 'text': 404}
# ************************************************************************
#
#
# ***************************************************************************************
# 	OCURRENCIAS DE VARIACIONES GRAMATICALES DE LAS PALABRAS
#
# Ocurrencias de las variaciones de hard:  {'hard': 3706, 'harder': 507, 'hardest': 140}
# Ocurrencias de las variaciones de serve:  {'serve': 1997, 'served': 1494, 'serving': 616, 'serves': 706}
# Ocurrencias de las variaciones de line:  {'line': 3201, 'liner': 1, 'lines': 1471, 'lined': 2}
# Ocurrencias de as variaciones de interest:  {'interest': 2131, 'interests': 369, 'interested': 4}
#
# ***************************************************************************************
#
#
#
# ***********************************************
# Datos erróneos:
#
#
# Instancias de hard antes de checkear las etiquetas  del contexto:  4333
# Instancia nº  21  de   hard  mal formateada.
# Instancia nº  110  de   hard  mal formateada.
# Instancia nº  196  de   hard  mal formateada.
# Instancia nº  892  de   hard  mal formateada.
# Instancia nº  999  de   hard  mal formateada.
# Instancia nº  1010  de   hard  mal formateada.
# Instancia nº  1028  de   hard  mal formateada.
# Instancia nº  1088  de   hard  mal formateada.
# Instancia nº  1170  de   hard  mal formateada.
# Instancia nº  1351  de   hard  mal formateada.
# Instancia nº  1807  de   hard  mal formateada.
# Instancia nº  2452  de   hard  mal formateada.
# Instancia nº  2602  de   hard  mal formateada.
# Instancia nº  2700  de   hard  mal formateada.
# Instancia nº  2899  de   hard  mal formateada.
# Instancia nº  3225  de   hard  mal formateada.
# Instancia nº  4030  de   hard  mal formateada.
# Instancia nº  4058  de   hard  mal formateada.
# Instancia nº  4090  de   hard  mal formateada.
# ***************************************************************
# Instancias de hard después de checkear las etiquetas  del contexto:  113050
# Instancias de line antes de checkear las etiquetas  del contexto:  4146
# Instancia nº  324  de   line  mal formateada.
# Instancia nº  391  de   line  mal formateada.
# Instancia nº  517  de   line  mal formateada.
# Instancia nº  559  de   line  mal formateada.
# Instancia nº  644  de   line  mal formateada.
# Instancia nº  681  de   line  mal formateada.
# Instancia nº  910  de   line  mal formateada.
# Instancia nº  986  de   line  mal formateada.
# Instancia nº  1065  de   line  mal formateada.
# Instancia nº  1197  de   line  mal formateada.
# Instancia nº  1202  de   line  mal formateada.
# Instancia nº  1229  de   line  mal formateada.
# Instancia nº  1241  de   line  mal formateada.
# Instancia nº  1307  de   line  mal formateada.
# Instancia nº  1454  de   line  mal formateada.
# Instancia nº  1471  de   line  mal formateada.
# Instancia nº  1585  de   line  mal formateada.
# Instancia nº  1599  de   line  mal formateada.
# Instancia nº  1630  de   line  mal formateada.
# Instancia nº  1684  de   line  mal formateada.
# Instancia nº  1752  de   line  mal formateada.
# Instancia nº  1812  de   line  mal formateada.
# Instancia nº  1867  de   line  mal formateada.
# Instancia nº  1962  de   line  mal formateada.
# Instancia nº  1967  de   line  mal formateada.
# Instancia nº  2001  de   line  mal formateada.
# Instancia nº  2006  de   line  mal formateada.
# Instancia nº  2025  de   line  mal formateada.
# Instancia nº  2135  de   line  mal formateada.
# Instancia nº  2136  de   line  mal formateada.
# Instancia nº  2138  de   line  mal formateada.
# Instancia nº  2163  de   line  mal formateada.
# Instancia nº  2169  de   line  mal formateada.
# Instancia nº  2184  de   line  mal formateada.
# Instancia nº  2185  de   line  mal formateada.
# Instancia nº  2221  de   line  mal formateada.
# Instancia nº  2230  de   line  mal formateada.
# Instancia nº  2258  de   line  mal formateada.
# Instancia nº  2271  de   line  mal formateada.
# Instancia nº  2282  de   line  mal formateada.
# Instancia nº  2285  de   line  mal formateada.
# Instancia nº  2294  de   line  mal formateada.
# Instancia nº  2305  de   line  mal formateada.
# Instancia nº  2306  de   line  mal formateada.
# Instancia nº  2307  de   line  mal formateada.
# Instancia nº  2308  de   line  mal formateada.
# Instancia nº  2309  de   line  mal formateada.
# Instancia nº  2335  de   line  mal formateada.
# Instancia nº  2336  de   line  mal formateada.
# Instancia nº  2382  de   line  mal formateada.
# Instancia nº  2394  de   line  mal formateada.
# Instancia nº  2413  de   line  mal formateada.
# Instancia nº  2416  de   line  mal formateada.
# Instancia nº  2419  de   line  mal formateada.
# Instancia nº  2469  de   line  mal formateada.
# Instancia nº  2476  de   line  mal formateada.
# Instancia nº  2518  de   line  mal formateada.
# Instancia nº  2541  de   line  mal formateada.
# Instancia nº  2549  de   line  mal formateada.
# Instancia nº  2564  de   line  mal formateada.
# Instancia nº  2574  de   line  mal formateada.
# Instancia nº  2621  de   line  mal formateada.
# Instancia nº  2706  de   line  mal formateada.
# Instancia nº  2707  de   line  mal formateada.
# Instancia nº  2708  de   line  mal formateada.
# Instancia nº  2718  de   line  mal formateada.
# Instancia nº  2719  de   line  mal formateada.
# Instancia nº  2730  de   line  mal formateada.
# Instancia nº  2731  de   line  mal formateada.
# Instancia nº  2754  de   line  mal formateada.
# Instancia nº  2757  de   line  mal formateada.
# Instancia nº  2759  de   line  mal formateada.
# Instancia nº  2760  de   line  mal formateada.
# Instancia nº  2761  de   line  mal formateada.
# Instancia nº  2771  de   line  mal formateada.
# Instancia nº  2772  de   line  mal formateada.
# Instancia nº  2774  de   line  mal formateada.
# Instancia nº  2791  de   line  mal formateada.
# Instancia nº  2792  de   line  mal formateada.
# Instancia nº  2793  de   line  mal formateada.
# Instancia nº  2799  de   line  mal formateada.
# Instancia nº  2809  de   line  mal formateada.
# Instancia nº  2810  de   line  mal formateada.
# Instancia nº  2811  de   line  mal formateada.
# Instancia nº  2835  de   line  mal formateada.
# Instancia nº  2843  de   line  mal formateada.
# Instancia nº  2844  de   line  mal formateada.
# Instancia nº  2882  de   line  mal formateada.
# Instancia nº  2889  de   line  mal formateada.
# Instancia nº  2918  de   line  mal formateada.
# Instancia nº  2919  de   line  mal formateada.
# Instancia nº  2920  de   line  mal formateada.
# Instancia nº  2924  de   line  mal formateada.
# Instancia nº  2926  de   line  mal formateada.
# Instancia nº  2936  de   line  mal formateada.
# Instancia nº  2953  de   line  mal formateada.
# Instancia nº  2955  de   line  mal formateada.
# Instancia nº  2956  de   line  mal formateada.
# Instancia nº  2957  de   line  mal formateada.
# Instancia nº  2975  de   line  mal formateada.
# Instancia nº  2978  de   line  mal formateada.
# Instancia nº  2981  de   line  mal formateada.
# Instancia nº  2995  de   line  mal formateada.
# Instancia nº  3008  de   line  mal formateada.
# Instancia nº  3011  de   line  mal formateada.
# Instancia nº  3036  de   line  mal formateada.
# Instancia nº  3054  de   line  mal formateada.
# Instancia nº  3057  de   line  mal formateada.
# Instancia nº  3058  de   line  mal formateada.
# Instancia nº  3081  de   line  mal formateada.
# Instancia nº  3087  de   line  mal formateada.
# Instancia nº  3091  de   line  mal formateada.
# Instancia nº  3099  de   line  mal formateada.
# Instancia nº  3102  de   line  mal formateada.
# Instancia nº  3106  de   line  mal formateada.
# Instancia nº  3124  de   line  mal formateada.
# Instancia nº  3140  de   line  mal formateada.
# Instancia nº  3142  de   line  mal formateada.
# Instancia nº  3188  de   line  mal formateada.
# Instancia nº  3207  de   line  mal formateada.
# Instancia nº  3248  de   line  mal formateada.
# Instancia nº  3249  de   line  mal formateada.
# Instancia nº  3253  de   line  mal formateada.
# Instancia nº  3258  de   line  mal formateada.
# Instancia nº  3262  de   line  mal formateada.
# Instancia nº  3278  de   line  mal formateada.
# Instancia nº  3290  de   line  mal formateada.
# Instancia nº  3305  de   line  mal formateada.
# Instancia nº  3306  de   line  mal formateada.
# Instancia nº  3318  de   line  mal formateada.
# Instancia nº  3320  de   line  mal formateada.
# Instancia nº  3323  de   line  mal formateada.
# Instancia nº  3324  de   line  mal formateada.
# Instancia nº  3325  de   line  mal formateada.
# Instancia nº  3326  de   line  mal formateada.
# Instancia nº  3337  de   line  mal formateada.
# Instancia nº  3355  de   line  mal formateada.
# Instancia nº  3356  de   line  mal formateada.
# Instancia nº  3359  de   line  mal formateada.
# Instancia nº  3360  de   line  mal formateada.
# Instancia nº  3362  de   line  mal formateada.
# Instancia nº  3367  de   line  mal formateada.
# Instancia nº  3382  de   line  mal formateada.
# Instancia nº  3425  de   line  mal formateada.
# Instancia nº  3426  de   line  mal formateada.
# Instancia nº  3477  de   line  mal formateada.
# Instancia nº  3490  de   line  mal formateada.
# Instancia nº  3513  de   line  mal formateada.
# Instancia nº  3516  de   line  mal formateada.
# Instancia nº  3526  de   line  mal formateada.
# Instancia nº  3529  de   line  mal formateada.
# Instancia nº  3530  de   line  mal formateada.
# Instancia nº  3538  de   line  mal formateada.
# Instancia nº  3539  de   line  mal formateada.
# Instancia nº  3547  de   line  mal formateada.
# Instancia nº  3551  de   line  mal formateada.
# Instancia nº  3568  de   line  mal formateada.
# Instancia nº  3589  de   line  mal formateada.
# Instancia nº  3592  de   line  mal formateada.
# Instancia nº  3619  de   line  mal formateada.
# Instancia nº  3621  de   line  mal formateada.
# Instancia nº  3623  de   line  mal formateada.
# Instancia nº  3624  de   line  mal formateada.
# Instancia nº  3625  de   line  mal formateada.
# Instancia nº  3680  de   line  mal formateada.
# Instancia nº  3686  de   line  mal formateada.
# Instancia nº  3698  de   line  mal formateada.
# Instancia nº  3708  de   line  mal formateada.
# Instancia nº  3778  de   line  mal formateada.
# Instancia nº  3781  de   line  mal formateada.
# Instancia nº  3802  de   line  mal formateada.
# Instancia nº  3836  de   line  mal formateada.
# Instancia nº  3935  de   line  mal formateada.
# Instancia nº  3951  de   line  mal formateada.
# Instancia nº  4076  de   line  mal formateada.
# Instancia nº  4136  de   line  mal formateada.
# ***************************************************************
# Instancias de line después de checkear las etiquetas  del contexto:  212983
# Instancias de serve antes de checkear las etiquetas  del contexto:  4378
# Instancia nº  18  de   serve  mal formateada.
# Instancia nº  24  de   serve  mal formateada.
# Instancia nº  133  de   serve  mal formateada.
# Instancia nº  150  de   serve  mal formateada.
# Instancia nº  151  de   serve  mal formateada.
# Instancia nº  214  de   serve  mal formateada.
# Instancia nº  255  de   serve  mal formateada.
# Instancia nº  275  de   serve  mal formateada.
# Instancia nº  323  de   serve  mal formateada.
# Instancia nº  412  de   serve  mal formateada.
# Instancia nº  552  de   serve  mal formateada.
# Instancia nº  607  de   serve  mal formateada.
# Instancia nº  655  de   serve  mal formateada.
# Instancia nº  664  de   serve  mal formateada.
# Instancia nº  752  de   serve  mal formateada.
# Instancia nº  762  de   serve  mal formateada.
# Instancia nº  774  de   serve  mal formateada.
# Instancia nº  881  de   serve  mal formateada.
# Instancia nº  890  de   serve  mal formateada.
# Instancia nº  956  de   serve  mal formateada.
# Instancia nº  973  de   serve  mal formateada.
# Instancia nº  1009  de   serve  mal formateada.
# Instancia nº  1041  de   serve  mal formateada.
# Instancia nº  1049  de   serve  mal formateada.
# Instancia nº  1054  de   serve  mal formateada.
# Instancia nº  1058  de   serve  mal formateada.
# Instancia nº  1078  de   serve  mal formateada.
# Instancia nº  1159  de   serve  mal formateada.
# Instancia nº  1164  de   serve  mal formateada.
# Instancia nº  1176  de   serve  mal formateada.
# Instancia nº  1197  de   serve  mal formateada.
# Instancia nº  1213  de   serve  mal formateada.
# Instancia nº  1243  de   serve  mal formateada.
# Instancia nº  1283  de   serve  mal formateada.
# Instancia nº  1292  de   serve  mal formateada.
# Instancia nº  1302  de   serve  mal formateada.
# Instancia nº  1378  de   serve  mal formateada.
# Instancia nº  1423  de   serve  mal formateada.
# Instancia nº  1433  de   serve  mal formateada.
# Instancia nº  1480  de   serve  mal formateada.
# Instancia nº  1492  de   serve  mal formateada.
# Instancia nº  1496  de   serve  mal formateada.
# Instancia nº  1499  de   serve  mal formateada.
# Instancia nº  1532  de   serve  mal formateada.
# Instancia nº  1537  de   serve  mal formateada.
# Instancia nº  1568  de   serve  mal formateada.
# Instancia nº  1618  de   serve  mal formateada.
# Instancia nº  1727  de   serve  mal formateada.
# Instancia nº  1729  de   serve  mal formateada.
# Instancia nº  1753  de   serve  mal formateada.
# Instancia nº  1776  de   serve  mal formateada.
# Instancia nº  1808  de   serve  mal formateada.
# Instancia nº  1928  de   serve  mal formateada.
# Instancia nº  1975  de   serve  mal formateada.
# Instancia nº  2072  de   serve  mal formateada.
# Instancia nº  2075  de   serve  mal formateada.
# Instancia nº  2178  de   serve  mal formateada.
# Instancia nº  2506  de   serve  mal formateada.
# Instancia nº  2570  de   serve  mal formateada.
# Instancia nº  2646  de   serve  mal formateada.
# Instancia nº  2868  de   serve  mal formateada.
# Instancia nº  2882  de   serve  mal formateada.
# Instancia nº  3067  de   serve  mal formateada.
# Instancia nº  3341  de   serve  mal formateada.
# Instancia nº  3604  de   serve  mal formateada.
# Instancia nº  3692  de   serve  mal formateada.
# Instancia nº  3952  de   serve  mal formateada.
# Instancia nº  3966  de   serve  mal formateada.
# Instancia nº  4015  de   serve  mal formateada.
# Instancia nº  4154  de   serve  mal formateada.
# Instancia nº  4164  de   serve  mal formateada.
# Instancia nº  4208  de   serve  mal formateada.
# Instancia nº  4224  de   serve  mal formateada.
# Instancia nº  4261  de   serve  mal formateada.
# Instancia nº  4274  de   serve  mal formateada.
# Instancia nº  4289  de   serve  mal formateada.
# ***************************************************************
# Instancias de serve después de checkear las etiquetas  del contexto:  197758
# Instancias de interest antes de checkear las etiquetas  del contexto:  2368
# ***************************************************************
# Instancias de interest después de checkear las etiquetas  del contexto:  72847

# %% [markdown]
# **Parte 2: extracción de características**

# %%
import string

hard_common = nltk.FreqDist([w.context[0] for w in hard])
line_common = nltk.FreqDist([w.context[0] for w in line])
interest_common = nltk.FreqDist([w.context[0] for w in interest])
serve_common = nltk.FreqDist([w.context[0] for w in serve])

hard_common = hard_common.most_common()
line_common = line_common.most_common()
interest_common = interest_common.most_common()
serve_common = serve_common.most_common()

print('Hard common: ', hard_common)
print('Line common: ', line_common)
print('Interest common: ', interest_common)
print('serve common: ', serve_common)

hard_most_common = []
line_most_common = []
interest_most_common = []
serve_most_common = []

STOP_FORMS = ['PRP$','RB','EX','WP','CD','TO','WRB','PRP','IN','DT','CC']
STOP_WORDS = ['q','most','that','which','today', "'d", "'ll", "'m", "'re", "'s", "'t", "'ve", '000', '1', '10', '2', 'I', 'also', "don'", 'n', 'one', 'said', 'say', 'says', 'us']
STOP_PUNCTUATION = ['``', '--', "''"]
#Función que elimina de la lista de palabras más comunes preposiciones, determinantes, etc.
def skipStopWords(common, amb_words):
  most_common = []
  for w in common:
    if ( (w[0][1] not in STOP_FORMS) and (w[0][0] not in STOP_WORDS) and (w[0][0] not in string.punctuation) and (w[0][0] not in STOP_PUNCTUATION) and (w[0][0] not in amb_words) ):
      most_common.append(w[0][0])
  return most_common

hard_most_common = skipStopWords(hard_common, dict_var_hard.keys())
line_most_common = skipStopWords(line_common, dict_var_line.keys())
serve_most_common = skipStopWords(serve_common, dict_var_serve.keys())
interest_most_common = skipStopWords(interest_common, dict_var_interest.keys())

print('\nPalabras más comunes en hard: ', hard_most_common)
print('\nPalabras más comunes en line: ', line_most_common)
print('\nPalabras más comunes en serve: ', serve_most_common)
print('\nPalabras más comunes en interest: ', interest_most_common)

#Se establece el número de palabras más frecuentes a 250
N=250
hard_250_common = hard_most_common[0:N]
serve_250_common = serve_most_common[0:N]
interest_250_common = interest_most_common[0:N]
line_250_common = line_most_common[0:N]
print('\nLista 6 palabras más comunes ***************************\n')
print('Lista de 6 palabras más comunes en hard: ', hard_250_common)
print('Lista de 6 palabras más comunes en line: ', line_250_common)
print('Lista de 6 palabras más comunes en serve: ', serve_250_common)
print('Lista de 6 palabras más comunes en interest: ', interest_250_common)
print('************************************************\n\n')

window_size = 2
#Lista de diccionarios de ngrams para las palabras ambiguas
ngram_pos_hard = []
ngram_pos_line = []
ngram_pos_serve = []
ngram_pos_interest = []

#Función que crea un diccionario con la aparición de las dos palabras posteriores y anteriores a la palabra ambigua

def prevNextWords(amb_word):
  i=0
  #Array con los diccionarios de cada palabra ambigua
  ngram_pos = []
  for w in amb_word:
    #diccionario de colocación con ventana 2 para cada contexto
    ngram = {}
    #posición  de la palabra ambigua en el contexto
    pos = int(w.position)
    context_size = len(w.context)-1
    if (pos-window_size >= 0):
      ngram.update({'contains('+w.context[pos-1][0]+')': True})
      ngram.update({'contains('+w.context[pos-2][0]+')': True})
    elif (pos-1 >=0):
      ngram.update({'contains('+w.context[pos-1][0]+')': True})
    if (pos+window_size <= context_size):
      ngram.update({'contains('+w.context[pos+1][0]+')': True})
      ngram.update({'contains('+w.context[pos+2][0]+')': True})
    elif (pos+1 <=context_size):
      ngram.update({'contains('+w.context[pos+1][0]+')': True})
    ngram_pos.append(ngram)
  return ngram_pos

ngram_pos_hard = prevNextWords(hard)
ngram_pos_line = prevNextWords(line)
ngram_pos_serve = prevNextWords(serve)
ngram_pos_interest = prevNextWords(interest)

print('\n\nEjemplos de diccionarios de colocación de las palabras ambiguas:')
print('Hard: ', ngram_pos_hard[0])
print('Line: ', ngram_pos_line[0])
print('Serve: ', ngram_pos_serve[0])
print('Interest: ', ngram_pos_interest[0])
# Out:
# Hard common:  [(('``', '``'), 22291), (('it', 'PRP'), 10904), (('the', 'DT'), 9655), (('but', 'CC'), 5036), (('i', 'PRP'), 2744), (('in', 'IN'), 2531), (('and', 'CC'), 1943), (('(', '('), 1753), (('if', 'IN'), 1493), (('he', 'PRP'), 1476), (('a', 'DT'), 1257), (('as', 'IN'), 1109), (('they', 'PRP'), 1080), (('that', 'DT'), 1058), (('there', 'EX'), 1030), (('for', 'IN'), 996), (('when', 'WRB'), 947), (('this', 'DT'), 930), (('she', 'PRP'), 927), (('even', 'RB'), 885), (('although', 'IN'), 841), (('with', 'IN'), 837), (('we', 'PRP'), 784), (('after', 'IN'), 740), (('while', 'IN'), 699), (('now', 'RB'), 556), (('one', 'CD'), 542), (('so', 'RB'), 540), (('to', 'TO'), 508), (('some', 'DT'), 497), (('what', 'WP'), 477), (('on', 'IN'), 468), (('since', 'IN'), 453), (('because', 'IN'), 438), (('still', 'RB'), 435), (('yet', 'RB'), 427), (('not', 'RB'), 402), (('you', 'PRP'), 372), (('these', 'DT'), 347), (('from', 'IN'), 312), (('most', 'JJS'), 290), (('at', 'IN'), 277), (('no', 'DT'), 270), (('despite', 'IN'), 247), (('her', 'PRP$'), 245), (('--', ':'), 239), (('here', 'RB'), 235), (('today', 'NN'), 232), (('all', 'DT'), 226), (('q', 'NN'), 223
# Line common:  [(('the', 'DT'), 27110), (('"', '"'), 16310), (('in', 'IN'), 10280), (('but', 'CC'), 9404), (('mr', 'NNP'), 6577), (('he', 'PRP'), 6548), (('it', 'PRP'), 5012), (('a', 'DT'), 4229), (('at', 'IN'), 3031), (('as', 'IN'), 2438), (('for', 'IN'), 2273), (('and', 'CC'), 2213), (('that', 'DT'), 2211), (('i', 'PRP'), 1470), (('one', 'CD'), 1373), (('sales', 'NNS'), 1301), (('some', 'DT'), 1299), (('they', 'PRP'), 1251), (('ibm', 'NNP'), 1250), (('so', 'RB'), 1184), (('there', 'EX'), 1166), (('this', 'DT'), 1158), (('she', 'PRP'), 1128), (('to', 'TO'), 1108), (('on', 'IN'), 1084), (('if', 'IN'), 1076), (('although', 'IN'), 1057), (('after', 'IN'), 1044), (('we', 'PRP'), 1011), (('last', 'JJ'), 1003), (('when', 'WRB'), 1001), (('while', 'IN'), 970), (('international', 'NNP'), 951), (('then', 'RB'), 899), (('many', 'JJ'), 885), (('its', 'PRP$'), 827), (('moreover', 'RB'), 788), (('american', 'NNP'), 771), (('chrysler', 'NNP'), 719), (('most', 'JJS'), 702), (('now', 'RB'), 682), (('analysts', 'NNS'), 681), (('gm', 'NNP'), 668), (('meanwhile', 'RB'), 666), (('terms', 'NNS'), 660), (('since', 'IN'), 657), (('such', 'JJ'), 651), (('however', 'RB'), 633), (('even', 'RB'), 630), (('no', 'DT'), 629), (('ford', 'NNP'), 625), (('an', 'DT'), 607), (('what', 'WP'), 602), (('those', 'DT'), 602), (('revenue', 'NN'), 592), (('indeed', 'RB'), 581), (('yet', 'RB'), 567), (('with', 'IN'), 551), (('these', 'DT'), 541), (('by', 'IN'), 522), (('ms', 'NNP'), 514), (('general', 'NNP'), 507), (('digital', 'NNP'), 471), (('compaq', 'NNP'), 463), (('his', 'PRP$'), 461), (('among', 'IN'), 432), (('you', 'PRP'), 424), (('under', 'IN'), 416), (('nevertheless', 'RB'), 407), (('despite', 'IN'), 405), (('all', 'DT'), 394), (('other', 'JJ'), 362), (('from', 'IN'), 351), (('reebok', 'NNP'), 349), (('officials', 'NNS'), 342), (('thus', 'RB'), 337), (('separately', 'RB'), 330), (('toyota', 'NNP'), 322), (('nissan', 'NNP'), 310), (('here', 'RB'), 307), (('last', 'NNP'), 307), (('more', 'RBR'), 305), (('mattel', 'NNP'), 302), (('once', 'RB'), 297), (('later', 'RB'), 293), (('another', 'DT'), 275), (('not', 'RB'), 273), (('still', 'RB'), 270), (('should', 'MD'), 266), (('new', 'JJ'), 263), (('computer', 'NNP'), 260), (('instead', 'RB'), 250), (('quaker', 'NNP'), 249), (('just', 'RB'), 247), (('tandy
267), (('sometimes', 'RB'), 265), (('through', 'IN'), 264), (('continue', 'VB'), 261), (('not', 'RB'), 260), (('her', 'PRP$'), 259), (('george', 'NNP'), 256), (('eventually', 'RB'), 255), (('president', 'NNP'), 255), (('taste', 'NN'), 250), (('instead', 'RB'), 249), (('other', 'JJ'), 249), (('their', 'PRP$'), 246), (('separately', 'RB'), 246), (('arrange', 'VB'), 245), (('every', 'DT'), 244), (('my', 'PRP$'), 243), (('later', 'RB'), 243), (('robert', 'NNP'), 242), (('new', 'JJ'), 233), (('indian', 'JJ'), 232), (('others', 'NNS'), 232), (('mrs', 'NNP'), 231), (('make', 'VB'), 231), (('first', 'NNP'), 220), (('next', 'JJ'), 217), (('how', 'WRB'), 216), (('members', 'NNS'), 213), (('about', 'IN'), 211), (('finally', 'RB'), 211), (('both', 'DT'), 209), (('neither', 'CC'), 208), (('until', 'IN'), 206), (('u', 'NNP'), 204), (('terms', 'NNS'), 200), (('top', 'JJ'), 197), (('american', 'NNP'), 196), (('arthur', 'NNP'), 194), (('general', 'NNP'), 193), (('garnish', 'NNP'), 191), (('chairman', 'NNP'), 188), (('let', 'VB'), 187), (('more', 'RBR'), 187), (('those', 'DT'), 187), (('everything', 'NN'), 185), (('also', 'RB'), 178), (('simmer', 'VB'), 176), (('only', 'RB'), 175), (('return', 'NN'), 173), (('like', 'IN'), 171), (('roast', 'VB'), 167), (('martin', 'NNP'), 166), (('cut', 'VB'), 165), (('nothing', 'NN'), 164), (('keep', 'VB'), 163), (('throughout', 'IN'), 161), (('sen', 'NNP'), 161), (('stir', 'NNP'), 160), (('suggested', 'VBN'), 159), (('favourite', 'NNP'), 159), (('being', 'VBG'), 157), (('few', 'JJ'), 156), (('strain', 'NNP'), 154), (('congress', 'NNP'), 153), (('gen', 'NNP'), 150), (('be', 'VB'), 149), (('whether', 'IN'), 149), (('further', 'RB'), 148), (('much', 'RB'), 146), (('try', 'VB'), 146), (('james', 'NNP'), 146), (('similarly', 'RB'), 145), (('of', 'IN'), 144), (('all', 'DT'), 143), (('administration', 'NN'), 143), (('cool', 'JJ'), 142), ( ...
#
# Palabras más comunes en hard:  ['asked', 'president', 'making', 'last', 'surface', 'bush', 'chairman', 'mr', 'do', 'is', 'robert', 'lap-top', 'yes', 'true', "'a", 'many', 'ferreira', 'craig', 'sen', 'finding', 'such', 'having', 'allegation', 'corrections', 'david', 'baker', 'current', 'getting', 'bill', 'school', 'enter', 'miss', 'life', 'nelson', 'according', 'japan', 'lottery', 'times', 'best', 'thanks', 'gentle', 'well', 'seems', 'women', 'other', 'proposing', 'pranks', 'pointing', 'becker', 'scherer', 'analysts', 'lendl', 'wilson', 'parents', 'grains', 'lawrence', 'worst', 'take', 'marketing', 'thun', 'calling', 'biden', 'gregory', 'saddam', 'sjs', 'mcdonnell', 'tip', 'understanding', 'ed', 'department', 'relentless', 'kirk', 'shakespeare', 'john', "'stick", "'not", 'several', 'sam', 'good', 'add', 'note', 'rev', 'smith', 'people', 'james', 'patty', 'democrats',
# Lista de 6 palabras más comunes en interest:  ['mr', 'profit', 'short', 'friday', 'analysts', 'traders', 'according', 'prosecutors', 'many', 'wednesday', 'tuesday', 'monday', 'western', 'first', 'lin', 'dealers', 'net', 'thursday', 'foreign', 'such', 'annualized', 'integrated', 'bond', 'james', 'manufacturers', 'gm', 'ms', 'richard', 'last', 'national', 'west', 'other', 'morgan', 'jaguar', 'american', 'viacom', 'ford', 'market', 'amoco', 'warner', 'kaneb', 'dow', 'officials', 'john', 'occidental', 'cie', 'c', 'itel', 'di', 'applications', 'students', 'texas', 'sotheby', 'allied', 'congress', 'investor', 'united', 'economists', 'major', 'whatever', 'beginning', 'healthvest', 'general', 'looking', 'speaking', 'sony', 'oryx', 'open', 'executives', 'citing', 'higher', 'new', 'investors', 'news', 'ima', 'florida', 'supporting', 'speculation', 'allianz', 'i', 'mccaw', 'high', 'artra', 'given', 'monroe', 'pantera', 'alpine', 'merrill', 'bond', 'home', 'david', 'london', 'lower', 'anticipating', 'dallas', 'signs', 'california', 'big', 'currency', 'banking', 'ray', 'buying', 'earlier', 'buoyed', 'maxus', 'odds', 'worse', 'lotus', 'current', 'campeau', 'holders', 'british', 'varity', 'mixed', 'rockefeller', 'secured', 'salomon', 'corporate', 'henley', 'short-term', 'proceeds', 'industry', 'data', 'chrysler', 'gary', 'bouygues', 'urging', 'republicans', 'michigan', 'bell', 'bonds', 'nick', 'kaneb', 'due', 'geoffrey', 'elsinore', 'neil', 'banks', 'star', 'equitable', 'karl', 'mci', 'quotron', 'underscoring', 'concern', 'jean', 'so-called', 'michael', 'yukio', 'bnl', 'several', 'tax', 'cooker', 'control', 'naomi', 'yes', 'ernst', 'rising', 'vickers', 'london', 'co', 'scott', 'ps', 'yields', 'environmental', 'textron', 'nbc', 'series', 'dallas-based', 'hca', 'raytheon', 'jerrold', 'moody', 'unocal', 'amex', 'saatchi', 'yesterday', 'generale', 'anchor', 'r', 'bert', 'bankamerica', 'guinness', 'loan', 'joao', 'cash-strapped', 'fletcher', 'amr', 'profit-taking', 'erc', 'transco', 'westinghouse', 'thermedics', 'columbia', 'unified', 'owen', 'ted', 'strategy', 'balances', 'democrats', 'hot', 'wells', 'mccaw', 'capital', 'kevin', 'frustrated', 'swissair', 'institutions', 'started', 'boston', 'leonard', 'rockwell', 'affiliated', 'smith', 'continental', 'telerate', 'shortages', 'mexico', 'donald', 'goldstar', 'southmark', 'fraser', 'abc', 'comsat', 'revenue', 'harris', 'pse', 'harcourt', 'wall', 'resorts', 'venezuela', 'faced', 'j', 'junk', 'international', 'crs', 'coats', 'minorco', 'supporters', 'seattle', 'vowing', 'horn', 'chevron', 'insight', 'gop', 'bridge', 'steels', 'heightened', 'meridian', 'accrued']
# ************************************************
#
#
#
#
# Ejemplos de diccionarios de colocación de las palabras ambiguas:
# Hard:  {"contains('s)": True, 'contains(that)': True, 'contains(to)': True, 'contains(do)': True}
# Line:  {'contains(safety)': True, 'contains(special)': True, 'contains(inside)': True, 'contains(the)': True}
# Serve:  {'contains(to)': True, 'contains(wiser)': True, 'contains(it)': True, 'contains(plain)': True}
# Interest:  {'contains(in)': True, 'contains(declines)': True, 'contains(rates)': True, 'contains(.)': True}

# %% [markdown]
# **Parte 3: entrenamiiento de clasificadores**

# %%
import random

#vectoor de características de colocación inicializados para cada palabra ambigua
features_col_hard = []
features_col_serve = []
features_col_line = []
features_col_interest = []

#Funciión que crea para cada sentido ambiguo de una palabra le asigna un vector de características de colocación
def createColData(word, features_w):
  i_w=0
  features_col = []
  for w in word:
    #Capturo solamente el primer sentido en caso de que haya varios
    sense = w.senses[0]
    #dict con las palabras previas y posteriiores
    features = features_w[i_w]
    features_col.append([features, sense])
    i_w+=1
  return features_col

features_col_hard = createColData(hard, ngram_pos_hard)
features_col_serve = createColData(serve, ngram_pos_serve)
features_col_line = createColData(line, ngram_pos_line)
features_col_interest = createColData(interest, ngram_pos_interest)

#se mezclan las instancias
random.shuffle(features_col_hard)
random.shuffle(features_col_line)
random.shuffle(features_col_interest)
random.shuffle(features_col_serve)

features_col_hard_train = []
features_col_hard_test = []

features_col_line_train = []
features_col_line_test = []

features_col_serve_train = []
features_col_serve_test = []

features_col_interest_train = []
features_col_interest_test = []

#20% para test, 80% para validación
features_col_hard_train = features_col_hard[:int(0.8*len(features_col_hard))]
features_col_hard_test = features_col_hard[int(0.8*len(features_col_hard)):]

features_col_line_train = features_col_line[:int(0.8*len(features_col_line))]
features_col_line_test = features_col_line[int(0.8*len(features_col_line)):]

features_col_serve_train = features_col_serve[:int(0.8*len(features_col_serve))]
features_col_serve_test = features_col_serve[int(0.8*len(features_col_serve)):]

features_col_interest_train = features_col_interest[:int(0.8*len(features_col_interest))]
features_col_interest_test = features_col_interest[int(0.8*len(features_col_interest)):]

nbc_col_hard = NaiveBayesClassifier.train(features_col_hard_train)
acc_nbc_col_hard = accuracy(nbc_col_hard, features_col_hard_test)

nbc_col_line = NaiveBayesClassifier.train(features_col_line_train)
acc_nbc_col_line = accuracy(nbc_col_line, features_col_line_test)

nbc_col_serve = NaiveBayesClassifier.train(features_col_serve_train)
acc_nbc_col_serve = accuracy(nbc_col_serve, features_col_serve_test)

nbc_col_interest = NaiveBayesClassifier.train(features_col_interest_train)
acc_nbc_col_interest = accuracy(nbc_col_interest, features_col_interest_test)

print('La accuracy para característcas de colocación de hard es: ', acc_nbc_col_hard)
print('La accuracy para característcas de colocación de line es: ', acc_nbc_col_line)
print('La accuracy para característcas de colocación de serve es: ', acc_nbc_col_serve)
print('La accuracy para característcas de colocación de interest es: ', acc_nbc_col_interest)

#Coprueba para cada instancia de la palabra ambigua si aparecen las 250 palabras más ambiiguas en el contexto
def fillFeaturesCommon(word, common_250):
  dict_array_common = []
  for w in word:
    dict_common = {}
    #Inicializo a falso las apariciones de las 6 palabras más comunes en el contexto
    for ws in common_250:
      dict_common.update({ws: False})
    for wc in w.context:
      #Si la palabra del contexto se corresponde con unas de las ás communes se indica su aparición en el dict
      if (wc[0] in dict_common.keys()):
        dict_common.update({wc[0]: True})
    #Agrego el dict al array de las instancias de la palabra ambigua
    dict_array_common.append(dict_common)
  return dict_array_common

dict_hard_array_common = []
dict_line_array_common = []
dict_serve_array_common = []
dict_interest_array_common = []

dict_hard_array_common = fillFeaturesCommon(hard, hard_250_common)
dict_line_array_common = fillFeaturesCommon(line, line_250_common)
dict_serve_array_common = fillFeaturesCommon(serve, serve_250_common)
dict_interest_array_common = fillFeaturesCommon(interest, interest_250_common)

print('\n\nInstancias de ejemplo de entrenamiento para hard:',len(dict_hard_array_common))
features_common_hard = []
features_common_line = []
features_common_serve = []
features_common_interest = []

def createCommonData(word, dict_array_common):
  i_w=0
  features_col = []
  for w in word:
    #Capturo solamente el primer sentido en caso de que haya varios
    sense = w.senses[0]
    #dict con las palabras previas y posteriiores
    features_col = dict_array_common[i_w]
    features_common_hard.append([features_col, sense])
    i_w+=1
  return features_common_hard

features_common_hard = createCommonData(hard, dict_hard_array_common)
features_common_line = createCommonData(line, dict_line_array_common)
features_common_serve = createCommonData(hard, dict_serve_array_common)
features_common_interest = createCommonData(interest, dict_interest_array_common)

#se mezclan las instancias
random.shuffle(features_common_hard)
random.shuffle(features_common_line)
random.shuffle(features_common_serve)
random.shuffle(features_common_interest)

#20% para test, 80% para validación
features_common_hard_train = features_common_hard[:int(0.8*len(features_common_hard))]
features_common_hard_test = features_common_hard[int(0.8*len(features_common_hard)):]

features_common_line_train = features_common_line[:int(0.8*len(features_common_line))]
features_common_line_test = features_common_line[int(0.8*len(features_common_line)):]

features_common_serve_train = features_common_serve[:int(0.8*len(features_common_serve))]
features_common_serve_test = features_common_serve[int(0.8*len(features_common_serve)):]

features_common_interest_train = features_common_interest[:int(0.8*len(features_common_interest))]
features_common_interest_test = features_common_interest[int(0.8*len(features_common_interest)):]


nbc_common_hard = NaiveBayesClassifier.train(features_common_hard_train)
acc_nbc_common_hard = accuracy(nbc_common_hard, features_common_hard_test)

nbc_common_line = NaiveBayesClassifier.train(features_common_line_train)
acc_nbc_common_line = accuracy(nbc_common_line, features_common_line_test)

nbc_common_serve = NaiveBayesClassifier.train(features_common_serve_train)
acc_nbc_common_serve = accuracy(nbc_common_serve, features_common_serve_test)

nbc_common_interest = NaiveBayesClassifier.train(features_common_interest_train)
acc_nbc_common_interest = accuracy(nbc_common_interest, features_common_interest_test)

print('\n\nLa accuracy para bag of words de hard es: ', acc_nbc_common_hard)
print('La accuracy para bag of words de line es: ', acc_nbc_common_line)
print('La accuracy para bag of words de serve es: ', acc_nbc_common_serve)
print('La accuracy para bag of words de interest es: ', acc_nbc_common_interest)
# Out:
# La accuracy para característcas de colocación de hard es:  0.9682883679787705
# La accuracy para característcas de colocación de line es:  0.9470150480080757
# La accuracy para característcas de colocación de serve es:  0.9551982200647249
# La accuracy para característcas de colocación de interest es:  0.9766643788606726
#
#
# Instancias de ejemplo de entrenaiento para hard: 113050
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-88aed449a26e> in <module>()
#     143
#     144 nbc_common_hard = NaiveBayesClassifier.train(features_common_hard_train)
# --> 145 acc_nbc_common_hard = accuracy(nbc_common_hard, features_common_hard_test)
#     146
#     147 nbc_common_line = NaiveBayesClassifier.train(features_common_line_train)
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/util.py in accuracy(classifier, gold)
#      85
#      86 def accuracy(classifier, gold):
# ---> 87     results = classifier.classify_many([fs for (fs, l) in gold])
#      88     correct = [l == r for ((fs, l), r) in zip(gold, results)]
#      89     if correct:
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/api.py in classify_many(self, featuresets)
#      75         :rtype: list(label)
#      76         """
# ---> 77         return [self.classify(fs) for fs in featuresets]
#      78
#      79     def prob_classify_many(self, featuresets):
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/api.py in <listcomp>(.0)
#      75         :rtype: list(label)
#      76         """
# ---> 77         return [self.classify(fs) for fs in featuresets]
#      78
#      79     def prob_classify_many(self, featuresets):
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/naivebayes.py in classify(self, featureset)
#      86
#      87     def classify(self, featureset):
# ---> 88         return self.prob_classify(featureset).max()
#      89
#      90     def prob_classify(self, featureset):
#
# /usr/local/lib/python3.6/dist-packages/nltk/classify/naivebayes.py in prob_classify(self, featureset)
#     112                 if (label, fname) in self._feature_probdist:
#     113                     feature_probs = self._feature_probdist[label, fname]
# --> 114                     logprob[label] += feature_probs.logprob(fval)
#     115                 else:
#     116                     # nb: This case will never come up if the
#
# KeyboardInterrupt:

# %% [markdown]
# **Parte 3: respuesta a cuestiones**
#
# *¿Cuál es el conjunto de características que aporta mejores resultados? ¿Por qué? *
#
# - El conjunto de características que apoorta mejores resultados es el de har de colocación, ya que solo tiene 3 posibles sentidos y además éstoos  no son múltiiples.
#
# *¿Cuál es el sentido más difícil de identificar? ¿Por qué?*
#
# - El sentido mmás difícil de identificar es el de line, ya que tiene mmuchos sentidos y algunos son múltiples.
#
# *¿Qué posibles mejoras se podrían aplicar para mejorar el rendimiento de los clasificadores creados? No es necesario que las implementes, solo que las comentes.*
#
# - Para las características de colocación se podrían excluir palabras como determinantes, artículos, caracteres de puntuación, etc que estuviesen colocados  antes o después de la palabra ambigua  o bien aumentar la  ventana (windows_size). Paralas característiicas basadas en bags of words podría aumentarse el número de palabras del vocabulario o ponderar estas de algún modo por el número de apariciones de las palabras en el contexto o su distancia a la palabra ambigua.
#
#
# *¿Por qué no es justo comparar directamente la exactitud aportada por los clasificadores que han aprendido diferentes palabras ambiguas?*
#
# - Porque la colocación y las palabras más comunes dependen de las frases de contexto, y estas son arbistrarias, de ejemplo. Además hay sentidos múltiples que dificultan aún más la tarea.
#
# *¿Cómo podrías hacerlo para que la comparación entre clasificadores que desambiguan palabras diferentes tenga sentido?*
#
# - Al existir en un sentido significados múltiples podría elegirse el sentido más común de entre los posibles o proporcioonar frases de coontextoopara cada uno de los posibles sentidos de la palabra ambigua.
#
# *Compara la exactitud de los clasificadores con la que proporcionaría un clasificador que asignara el sentido de forma aleatoria. ¿Cuál sería el mejor clasificador tomando como referencia (baseline), el clasificador aleatorio?*
#
# - Un clasificador que asignase el sentido de forma aleatoria llevado al límite sería peor, puesto que no habría características comunes ni uniiformidad para formar los vectores de características (colocación y bag of words). El clasificador aleatorio funcionaría mejor parapalabras con pocos sentidos y sin sentidos múltiples.

# %% [markdown]
# **Parte 4:**
#
# *¿Cuáles son las limitaciones de los clasificadores que has creado para la desambiguación del sentido de las palabras?*
#
# - No aprende sentidos múltiples, sino  que se toma como referencia si hay varios sentidos el primero de ellos. Por motivos de tiempo de procesamiento podría aumentarse el tamaño del window_size y aumentar la accuracy del clasificador.
